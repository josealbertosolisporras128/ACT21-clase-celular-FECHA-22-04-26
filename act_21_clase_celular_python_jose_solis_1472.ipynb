# %% [markdown]
# <a href="https://colab.research.google.com/github/josealbertosolisporras128/ACT21-clase-celular-FECHA-22-04-26/blob/main/act_21_clase_celular_python_jose_solis_1472.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### jose solis NL 51 fecha 22/abr/26
# ## clase celular
# ![texto del vinculo](https://raw.githubusercontent.com/josealbertosolisporras128/ACT21-clase-celular-FECHA-22-04-26/refs/heads/main/infoClaseCeular.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 15", 1000)
# llamadas a las funciones para cada objeto celular 1 y celular 2
print("celular 1: ")
cel1.mostrar_info()
cel1.encender()

print("celular 2: ")
cel2.mostrar_info()
cel2.encender()

print("programa terminado")
print("creador de software por Jose Solis NL = 51")
# Out:
# celular 1:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
# celular 2:
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# programa terminado
# creador de software por Jose Solis NL = 51

# %% [markdown]
# ![texto del enlace](https://raw.githubusercontent.com/josealbertosolisporras128/ACT21-clase-celular-FECHA-22-04-26/refs/heads/main/LogicaFuncionamiento.png)
